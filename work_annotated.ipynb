# %% [markdown]
# ### Importing the important libraries

# %% [markdown]
# ###  Importing Libraries
# This cell imports the required Python libraries for the project.

# %%
import numpy as np
import pandas as pd # pandas is used for table manipulation like excel sheet manipulation it provide dataframe in which we can manipulate data
#what is library 
# library predefined funcitons or predifned modules or files which can able to certain levle of task 
#why we use library
# to save time and effort and to increase code reusablility

# %% [markdown]
# ###  Data Loding

# %%
movies =pd.read_csv(r'C:\Users\shiva\OneDrive\Documents\Material\Data_Science\Project\tmdb_5000_movies.csv')
credits = pd.read_csv(r'C:\Users\shiva\OneDrive\Documents\Material\Data_Science\Project\tmdb_5000_credits.csv')

# %% [markdown]
# ###  Understanding the datsets

# %%
movies.head(5) # it will show first 5 rows of the data
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
movies.head(1)['overview'].values # it will show first row of the tag line column
# Out:
# array(['In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization.'],
#       dtype=object)

# %%
movies.head(1)['genres'].values # it will show first row of the tag line column
# Out:
# array(['[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'],
#       dtype=object)

# %%
credits.head(5) # it will show first 5 rows of the data
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %% [markdown]
# ###  Understanding how the column cast is arranged

# %%
credits.head(1)['cast'].values # it will show first row of the data in cast column
# Out:
# array(['[{"cast_id": 242, "character": "Jake Sully", "credit_id": "5602a8a7c3a3685532001c9a", "gender": 2, "id": 65731, "name": "Sam Worthington", "order": 0}, {"cast_id": 3, "character": "Neytiri", "credit_id": "52fe48009251416c750ac9cb", "gender": 1, "id": 8691, "name": "Zoe Saldana", "order": 1}, {"cast_id": 25, "character": "Dr. Grace Augustine", "credit_id": "52fe48009251416c750aca39", "gender": 1, "id": 10205, "name": "Sigourney Weaver", "order": 2}, {"cast_id": 4, "character": "Col. Quaritch", "credit_id": "52fe48009251416c750ac9cf", "gender": 2, "id": 32747, "name": "Stephen Lang", "order": 3}, {"cast_id": 5, "character": "Trudy Chacon", "credit_id": "52fe48009251416c750ac9d3", "gender": 1, "id": 17647, "name": "Michelle Rodriguez", "order": 4}, {"cast_id": 8, "character": "Selfridge", "credit_id": "52fe48009251416c750ac9e1", "gender": 2, "id": 1771, "name": "Giovanni Ribisi", "order": 5}, {"cast_id": 7, "character": "Norm Spellman", "credit_id": "52fe48009251416c750ac9dd", "
# ...

# %% [markdown]
# ###  Understanding how the column crew is arranged

# %%
credits.head(1)['crew'].values # it will show first row of the data in cast column
# Out:
# array(['[{"credit_id": "52fe48009251416c750aca23", "department": "Editing", "gender": 0, "id": 1721, "job": "Editor", "name": "Stephen E. Rivkin"}, {"credit_id": "539c47ecc3a36810e3001f87", "department": "Art", "gender": 2, "id": 496, "job": "Production Design", "name": "Rick Carter"}, {"credit_id": "54491c89c3a3680fb4001cf7", "department": "Sound", "gender": 0, "id": 900, "job": "Sound Designer", "name": "Christopher Boyes"}, {"credit_id": "54491cb70e0a267480001bd0", "department": "Sound", "gender": 0, "id": 900, "job": "Supervising Sound Editor", "name": "Christopher Boyes"}, {"credit_id": "539c4a4cc3a36810c9002101", "department": "Production", "gender": 1, "id": 1262, "job": "Casting", "name": "Mali Finn"}, {"credit_id": "5544ee3b925141499f0008fc", "department": "Sound", "gender": 2, "id": 1729, "job": "Original Music Composer", "name": "James Horner"}, {"credit_id": "52fe48009251416c750ac9c3", "department": "Directing", "gender": 2, "id": 2710, "job": "Director", "name": "James C
# ...

# %%
movies.shape
# Out:
# (4803, 20)

# %%
credits.shape
# Out:
# (4803, 4)

# %% [markdown]
# ### Merging the credits and movies into a single dataframe for better further analysis.

# %%
movies = movies.merge(credits,on='title') #mergining on the basis of the common column title
# it will merge the two dataframes on the basis of the common column title

# %%
movies.shape
# Out:
# (4809, 23)

# %%
movies.head(1)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  ... runtime  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...  ...   162.0
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
#
#                        tagline   title vote_average vote_count movie_id  \
# 0  Enter the World of Pandora.  Avatar          7.2      11800    19995
#
# ...

# %% [markdown]
# ### Taking the important features that are important to our further analysis.

# %%
#genres
#id 
#keywords
#title 
#overview
#cast 
#crew
#will take the only the important columns and remove the rest of the columns 
movies = movies[['movie_id','title','overview','genres','keywords','cast','crew']]

# %% [markdown]
# ### New Dataframe info

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4809 entries, 0 to 4808
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  4809 non-null   int64
#  1   title     4809 non-null   object
#  2   overview  4806 non-null   object
#  3   genres    4809 non-null   object
#  4   keywords  4809 non-null   object
#  5   cast      4809 non-null   object
#  6   crew      4809 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 263.1+ KB

# %%
movies.shape
# Out:
# (4809, 7)

# %% [markdown]
# ### Handling Missing Values: Detection and Cleaning

# %%
movies.isnull().sum() # it will show the null values in the data
# Out:
# movie_id    0
# title       0
# overview    3
# genres      0
# keywords    0
# cast        0
# crew        0
# dtype: int64

# %% [markdown]
# ##  Removing Rows with Missing Movie Overviews (Minimal Impact on Dataset)
# We observed that only a small number of movies have missing values in the `overview` column.
# Since this column provides a textual summary that's useful for content-based filtering, and the number of missing entries is very low,
# we can safely remove these rows without significantly affecting our dataset or model performance.

# %%
movies.dropna(inplace=True) # it will drop the null values in the data
movies.isnull().sum() # it will show the null values in the data
# Out:
# movie_id    0
# title       0
# overview    0
# genres      0
# keywords    0
# cast        0
# crew        0
# dtype: int64

# %%
movies.duplicated().sum() # it will show the duplicate values in the data
# Out:
# 0

# %% [markdown]
# Cheked for duplicate values and as there are no duplicate values so we do not do anything.

# %% [markdown]
# ### Further preprocessing
# This attempting to understand the genre column and will take only the name of the genre of the films.

# %%
movies.iloc[0].genres # it will show the first row of the data in genres column
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %% [markdown]
# #### Converting Stringified Lists to Python Lists using `ast.literal_eval()`
# We use the built-in `ast` (Abstract Syntax Trees) module to safely parse stringified Python objects (like lists of dictionaries) into actual Python lists.
# This function `convert()` specifically extracts the `'name'` field from each dictionary within the stringified list.
#
#  **Why this is needed:**
# In the dataset, columns like `genres`, `keywords`, `cast`, and `crew` are stored as strings that look like lists of dictionaries.
# To work with them effectively, we first convert them into real Python list objects.

# %%
import ast
# ast is a built-in library in Python that allows you to parse and process Python expressions
def convert(obj):
    L = []
    for i in ast.literal_eval(obj):
        L.append(i['name'])
    return L

# %% [markdown]
# Taking only the name of the genres

# %%
movies['genres'] = movies['genres'].apply(convert) # it will convert the string to list of dictionaries

# %% [markdown]
# Applying the same above things to keywords too as genre.

# %%
movies['keywords'] = movies['keywords'].apply(convert) # it will convert the string to list of dictionaries

# %% [markdown]
# The new modified dataframe

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %% [markdown]
# ### Extracting Top 3 Cast Members from the Cast Feature
# The `cast` column contains a stringified list of dictionaries, where each dictionary holds information about an actor.
#
#  **Goal:**
# We only want the **top 3 actors** for each movie, and we will extract just their `name` fields for simplicity and relevance.
#
# This helps in:
# - Reducing noise from less important cast members.
# - Representing each movie with its key actors, which can aid in similarity-based recommendations.

# %%
import ast
# ast is a built-in library in Python that allows you to parse and process Python expressions
def convert3(obj):
    L = []
    counter =0
    for i in ast.literal_eval(obj):
        if counter != 3:
            L.append(i['name'])
            counter += 1
        else:
            break
    return L

# %%
movies['cast'] = movies['cast'].apply(convert3) # it will convert the string to list of dictionaries

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %% [markdown]
# ###  Extracting Director Name from the Crew Feature
# The `crew` column contains a stringified list of dictionaries, with each entry representing a crew member and their job.
#
#  **Goal:**
# We want to extract only the **director's name** for each movie, as the director plays a key role in defining the movie's style and content.
#
#  **Why this is important:**
# Including the director helps improve the quality of content-based recommendations, especially when users tend to prefer movies by the same filmmaker.

# %%
movies['crew'][0]
# Out:
# '[{"credit_id": "52fe48009251416c750aca23", "department": "Editing", "gender": 0, "id": 1721, "job": "Editor", "name": "Stephen E. Rivkin"}, {"credit_id": "539c47ecc3a36810e3001f87", "department": "Art", "gender": 2, "id": 496, "job": "Production Design", "name": "Rick Carter"}, {"credit_id": "54491c89c3a3680fb4001cf7", "department": "Sound", "gender": 0, "id": 900, "job": "Sound Designer", "name": "Christopher Boyes"}, {"credit_id": "54491cb70e0a267480001bd0", "department": "Sound", "gender": 0, "id": 900, "job": "Supervising Sound Editor", "name": "Christopher Boyes"}, {"credit_id": "539c4a4cc3a36810c9002101", "department": "Production", "gender": 1, "id": 1262, "job": "Casting", "name": "Mali Finn"}, {"credit_id": "5544ee3b925141499f0008fc", "department": "Sound", "gender": 2, "id": 1729, "job": "Original Music Composer", "name": "James Horner"}, {"credit_id": "52fe48009251416c750ac9c3", "department": "Directing", "gender": 2, "id": 2710, "job": "Director", "name": "James Cameron"
# ...

# %%
import ast
# ast is a built-in library in Python that allows you to parse and process Python expressions
def fetch_director(obj):
    L = []
    counter =0
    for i in ast.literal_eval(obj):
        if  i['job'] == 'Director':
            L.append(i['name'])
            break
    return L

# %%
movies['crew'].apply(fetch_director)
# Out:
# 0           [James Cameron]
# 1          [Gore Verbinski]
# 2              [Sam Mendes]
# 3       [Christopher Nolan]
# 4          [Andrew Stanton]
#                ...
# 4804     [Robert Rodriguez]
# 4805         [Edward Burns]
# 4806          [Scott Smith]
# 4807          [Daniel Hsia]
# 4808     [Brian Herzlinger]
# Name: crew, Length: 4806, dtype: object

# %%
movies['crew'] = movies['crew'].apply(fetch_director) # it will convert the string to list of dictionaries
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
movies['overview'].apply(lambda x: x.split()) # it will split the string to list of words
# Out:
# 0       [In, the, 22nd, century,, a, paraplegic, Marin...
# 1       [Captain, Barbossa,, long, believed, to, be, d...
# 2       [A, cryptic, message, from, Bond’s, past, send...
# 3       [Following, the, death, of, District, Attorney...
# 4       [John, Carter, is, a, war-weary,, former, mili...
#                               ...
# 4804    [El, Mariachi, just, wants, to, play, his, gui...
# 4805    [A, newlywed, couple's, honeymoon, is, upended...
# 4806    ["Signed,, Sealed,, Delivered", introduces, a,...
# 4807    [When, ambitious, New, York, attorney, Sam, is...
# 4808    [Ever, since, the, second, grade, when, he, fi...
# Name: overview, Length: 4806, dtype: object

# %%
movies['overview'] = movies['overview'].apply(lambda x: x.split()) # it will convert the string to list of dictionaries
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %% [markdown]
# ###  Removing Space from Names to Avoid Recommendation Confusion
# Sometimes, different individuals can have similar or partially matching names (e.g., `'Sam Worthington'` vs `'Sam Mendes'`).
# If we treat these names as space-separated tokens, it may lead to incorrect matches or recommendations.
#
#  **Solution:**
# We **remove spaces** from all names (e.g., `'Sam Worthington'` → `'SamWorthington'`) to treat each name as a **unique single token**.
#
#  **Why this is important:**
# This avoids mixing up distinct individuals in vector-based similarity models like TF-IDF or CountVectorizer, ensuring more accurate content-based recommendations.

# %% [markdown]
# ### Removing Spaces in Genre, Keywords, Cast, and Crew Names for Consistency
# To maintain consistency and prevent issues in text vectorization (like TF-IDF or CountVectorizer),
# we remove spaces within individual names or terms across the following columns:
# - `genres`
# - `keywords`
# - `cast`
# - `crew`
#
#  **Implementation:**
# Using `lambda` with `.apply()`, we replace `" "` with `""` in each list element.
#
#  **Why this matters:**
# Models treat space-separated words as different tokens.
# For example, `"Science Fiction"` becomes `["Science", "Fiction"]` which is misleading. By removing the space (`"ScienceFiction"`), we preserve its identity as a single genre.
#
# This step ensures better feature representation and avoids ambiguity during vectorization and similarity calculations.

# %%
movies['genres'] = movies['genres'].apply(lambda x: [i.replace(" ","")for i in x]) # it will convert the string to list
movies['keywords'] = movies['keywords'].apply(lambda x: [i.replace(" ","")for i in x]) # it will convert the string to list
movies['cast'] = movies['cast'].apply(lambda x: [i.replace(" ","")for i in x]) # it will convert the string to list
movies['crew'] = movies['crew'].apply(lambda x: [i.replace(" ","")for i in x]) # it will convert the string to list

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
# 2                    [Action, Adventure, Crime]
# 3              [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, ScienceFiction]
#
# ...

# %% [markdown]
# ### Creating the 'Tags' Feature by Combining Multiple Columns
# To form a comprehensive movie profile, we concatenate the following columns into a new feature `tags`:
# - `overview`
# - `genres`
# - `keywords`
# - `cast`
# - `crew`
#
# **Implementation:**
# By using the `+` operator, we combine all these columns into a single string for each movie.
#
#  **Why this is important:**
# The `tags` feature now contains a rich and unified representation of a movie's content, which will be critical for similarity-based recommendations. It consolidates key information into one vector, making it easier for models to compare movies based on their attributes.

# %%
movies['tags'] = movies['overview'] + movies['genres'] + movies['keywords'] + movies['cast'] + movies['crew'] # it will concat the columns to create a new column

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
# 2                    [Action, Adventure, Crime]
# 3              [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, ScienceFiction]
#
# ...

# %% [markdown]
# ### Creating a New DataFrame for Analysis: Selecting Relevant Columns
# To focus on the most important features for our recommendation system, we create a new DataFrame `new_df` by selecting the following columns:
# - `movie_id`
# - `title`
# - `tags`
#
# **Purpose:**
# This new DataFrame contains only the relevant information (movie ID, title, and tags), simplifying further analysis and processing.
#
# **Why this matters:**
# By narrowing down to the essential features, we streamline the recommendation process, making it easier to work with and improving computational efficiency in subsequent steps.

# %%
new_df = movies[['movie_id','title','tags']] # it will create a new dataframe with the selected columns
new_df
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4804      9367                               El Mariachi
# 4805     72766                                 Newlyweds
# 4806    231617                 Signed, Sealed, Delivered
# 4807    126186                          Shanghai Calling
# 4808     25975                         My Date with Drew
#
#                                                    tags
# 0     [In, the, 22nd, century,, a, paraplegic, Marin...
# 1     [Captain, Barbossa,, long, believed, to, be, d...
# 2     [A, cryptic, message, from, Bond’s, past, send...
# ...

# %% [markdown]
# ### Converting Tags List to a Single String for Text Vectorization
# The `tags` column currently contains a list of words (genres, cast, crew, keywords, etc.) for each movie.
# We now convert this list into a single space-separated string using `" ".join()`.
#
# **Purpose:**
# Text vectorization techniques like **CountVectorizer** or **TF-IDF** require input as a string of text, not a list.
# This step prepares the data for such models by transforming lists into a format suitable for text processing.
#
# **Example:**
# Before → `['Action', 'Adventure', 'JamesCameron', 'SamWorthington']`
# After → `"Action Adventure JamesCameron SamWorthington"`

# %%
new_df['tags'] = new_df['tags'].apply(lambda x: " ".join(x)) # it will join the list to string
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_2176\2416488869.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(lambda x: " ".join(x)) # it will join the list to string

# %%
new_df['tags'][0]
# Out:
# 'In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization. Action Adventure Fantasy ScienceFiction cultureclash future spacewar spacecolony society spacetravel futuristic romance space alien tribe alienplanet cgi marine soldier battle loveaffair antiwar powerrelations mindandsoul 3d SamWorthington ZoeSaldana SigourneyWeaver JamesCameron'

# %%
new_df['tags'] = new_df['tags'].apply(lambda x: x.lower()) # it will convert the string to lower case
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_2176\1914318615.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(lambda x: x.lower()) # it will convert the string to lower case

# %%
new_df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags
# 0  in the 22nd century, a paraplegic marine is di...
# 1  captain barbossa, long believed to be dead, ha...
# 2  a cryptic message from bond’s past sends him o...
# 3  following the death of district attorney harve...
# 4  john carter is a war-weary, former military ca...

# %%
new_df['tags'][0]
# Out:
# 'in the 22nd century, a paraplegic marine is dispatched to the moon pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization. action adventure fantasy sciencefiction cultureclash future spacewar spacecolony society spacetravel futuristic romance space alien tribe alienplanet cgi marine soldier battle loveaffair antiwar powerrelations mindandsoul 3d samworthington zoesaldana sigourneyweaver jamescameron'

# %%
new_df['tags'][1]
# Out:
# "captain barbossa, long believed to be dead, has come back to life and is headed to the edge of the earth with will turner and elizabeth swann. but nothing is quite as it seems. adventure fantasy action ocean drugabuse exoticisland eastindiatradingcompany loveofone'slife traitor shipwreck strongwoman ship alliance calypso afterlife fighter pirate swashbuckler aftercreditsstinger johnnydepp orlandobloom keiraknightley goreverbinski"

# %% [markdown]
# Now converting the tags into the vectors and each movie is related to each movies in the list and gets the score and on the basis of better score we will take the move

# %% [markdown]
# ###  Importing Libraries
# This cell imports the required Python libraries for the project.

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# ###  Creating CountVectorizer for Text Feature Extraction
# We initialize `CountVectorizer` with:
# - `max_features=5000` to keep the top 5000 frequent words
# - `stop_words='english'` to remove common English words (like "the", "and", etc.)
#
# This converts text data into numerical vectors for similarity calculation.

# %%
cv = CountVectorizer(max_features=5000,stop_words='english') # it will create a count vectorizer object with the max features of 5000 and stop words as english

# %% [markdown]
# ### Converting Tags to Numerical Vectors
# We apply `CountVectorizer` to the `tags` column to transform the text into numerical feature vectors.
#
#  `cv.fit_transform()` learns the vocabulary and transforms the text into a 2D array of word counts for each movie.

# %%
vectors = cv.fit_transform(new_df['tags']).toarray()

# %%
vectors[0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %% [markdown]
# ###  Displaying All Extracted Features
# We print all the words (features) extracted by `CountVectorizer` using `get_feature_names_out()`.

# %%
for i in cv.get_feature_names_out():
    print(i)
# Out:
# 000
# 007
# 10
# 100
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 18th
# 19
# 1930s
# 1940s
# 1950
# 1950s
# 1960s
# 1970s
# 1980
# 1980s
# 1985
# 1990s
# 1999
# 19th
# 19thcentury
# 20
# 200
# 2009
# 20th
# 24
# 25
# 30
# 300
# 3d
# 40
# 50
# 500
# 60
# 60s
# 70
# 70s
# aaron
# aaroneckhart
# abandoned
# abducted
# abigailbreslin
# abilities
# ability
# able
# aboard
# abuse
# abusive
# academy
# accept
# accepted
# accepts
# access
# accident
# accidental
# accidentally
# accompanied
# accomplish
# account
# accountant
# accused
# ace
# achieve
# act
# acting
# action
# actionhero
# actions
# activist
# activities
# activity
# actor
# actors
# actress
# acts
# actual
# actually
# adam
# adams
# adamsandler
# adamshankman
# adaptation
# adapted
# addict
# addicted
# addiction
# adolescence
# adolescent
# adopt
# adopted
# adoption
# adopts
# adrienbrody
# adult
# adultanimation
# adultery
# adulthood
# adults
# advantage
# adventure
# adventures
# advertising
# advice
# affair
# ...

# %%
# %pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ###  Importing Libraries
# This cell imports the required Python libraries for the project.

# %%
import nltk

# %% [markdown]
# ### Initializing Porter Stemmer for Word Normalization
# We use NLTK’s `PorterStemmer` to reduce words to their root form (e.g., "running" → "run") for better text matching.

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
new_df['tags']
# Out:
# 0       in the 22nd century, a paraplegic marine is di...
# 1       captain barbossa, long believed to be dead, ha...
# 2       a cryptic message from bond’s past sends him o...
# 3       following the death of district attorney harve...
# 4       john carter is a war-weary, former military ca...
#                               ...
# 4804    el mariachi just wants to play his guitar and ...
# 4805    a newlywed couple's honeymoon is upended by th...
# 4806    "signed, sealed, delivered" introduces a dedic...
# 4807    when ambitious new york attorney sam is sent t...
# 4808    ever since the second grade when he first saw ...
# Name: tags, Length: 4806, dtype: object

# %%
ps.stem('loving')
# Out:
# 'love'

# %% [markdown]
# ### Stemming Words in the 'tags' Column
# We define the `stem()` function to reduce words to their root form using the `PorterStemmer`.
# This is applied to the `tags` column to normalize the text data for better similarity calculations.

# %%
def stem(text):
    y =[]
    for i in text.split():
        y.append(ps.stem(i))
    return " ".join(y)

# %%
new_df['tags'] = new_df['tags'] = new_df['tags'].apply(stem)
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_2176\3186334729.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'] = new_df['tags'].apply(stem)

# %% [markdown]
# ###  Calculating Cosine Similarity Between Movies
# We use `cosine_similarity` from `sklearn` to compute similarity scores between movies based on their `tags` vectors.
# This will help in identifying movies with similar content.

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vectors)

# %%
similarity[0]
# Out:
# array([1.        , 0.08964215, 0.05976143, ..., 0.02519763, 0.02817181,
#        0.        ])

# %% [markdown]
# ### Calculating Cosine Similarity Between Movies
# We compute the **cosine similarity** between movie vectors using `cosine_similarity()`, which measures the similarity between movies based on their `tags`.

# %%
sorted (similarity[0],reverse=True)
# Out:
# [1.0,
#  0.26089696604360174,
#  0.2581988897471611,
#  0.25302403842552984,
#  0.25110592822973776,
#  0.24944382578492943,
#  0.24397501823713333,
#  0.243599382882345,
#  0.23904572186687872,
#  0.2344036154692477,
#  0.22677868380553634,
#  0.2238868314198225,
#  0.22230800575069137,
#  0.22190115272469205,
#  0.22131333406899523,
#  0.2193633988428327,
#  0.2173253797873328,
#  0.21653278478430665,
#  0.2164218276749025,
#  0.2162249910469341,
#  0.2162249910469341,
#  0.21602468994692864,
#  0.21602468994692864,
#  0.21251185925162067,
#  0.2114722130550724,
#  0.21147221305507238,
#  0.21096325392232296,
#  0.2059714602177749,
#  0.20291986247835692,
#  0.202837021134844,
#  0.19920476822239894,
#  0.19889806323953876,
#  0.1980534816610477,
#  0.19518001458970666,
#  0.19518001458970666,
#  0.19451950503185494,
#  0.1938916835823703,
#  0.19320245583349133,
#  0.19317811536651802,
#  0.1916629694999819,
#  0.1901597073139162,
#  0.18935242733246033,
#  0.1889822365046136,
# ...

# %% [markdown]
# ### Using Enumerate to Retain Indices While Sorting
# We use `enumerate()` to retain the index of each similarity score, ensuring we don't lose track of movie positions when sorting by similarity.

# %%
list(enumerate(similarity[0]))
# Out:
# [(0, 1.0),
#  (1, 0.08964214570007951),
#  (2, 0.059761430466719674),
#  (3, 0.03984095364447979),
#  (4, 0.1825741858350554),
#  (5, 0.1183452670827877),
#  (6, 0.02258769757263128),
#  (7, 0.1763834207376394),
#  (8, 0.061721339984836754),
#  (9, 0.07644707871564382),
#  (10, 0.11769797726729994),
#  (11, 0.081199794294115),
#  (12, 0.09583148474999097),
#  (13, 0.04733810683311508),
#  (14, 0.11428571428571427),
#  (15, 0.05096471914376255),
#  (16, 0.08226127456606226),
#  (17, 0.15026857675938213),
#  (18, 0.1129384878631564),
#  (19, 0.08728715609439694),
#  (20, 0.058167505074711086),
#  (21, 0.09583148474999097),
#  (22, 0.07049073768502413),
#  (23, 0.09583148474999097),
#  (24, 0.0563436169819011),
#  (25, 0.036454130828824455),
#  (26, 0.17142857142857143),
#  (27, 0.18935242733246033),
#  (28, 0.12555296411486888),
#  (29, 0.07100716024967263),
#  (30, 0.07319250547113999),
#  (31, 0.16265001215808886),
#  (32, 0.09116846116771035),
#  (33, 0.10350983390135313),
# ...

# %% [markdown]
# ### Sorting Movies by Similarity Score
# We sort the movies based on their similarity to the first movie (in descending order) using `enumerate()` to retain the indices.
# The result shows the top 5 most similar movies, excluding the first movie itself.

# %%
sorted(list(enumerate(similarity[0])),reverse= True,key = lambda x:x[1])[1:6]
# Out:
# [(539, 0.26089696604360174),
#  (1194, 0.2581988897471611),
#  (507, 0.25302403842552984),
#  (260, 0.25110592822973776),
#  (1216, 0.24944382578492943)]

# %% [markdown]
# ### Sorting Movies by Similarity Score
# We sort the movies based on their similarity to the first movie (in descending order) using `enumerate()` to retain the indices.
# The result shows the top 5 most similar movies, excluding the first movie itself.

# %%
def recommend(movie):
    movie_index = new_df[new_df['title'] == movie].index[0]
    distances = similarity[movie_index]
    movies_list = sorted(list(enumerate(distances)),reverse= True,key = lambda x:x[1])[1:6]

    for i in movies_list:
        print(new_df.iloc[i[0]].title)

# %% [markdown]
# ### Recommending Movies Similar to 'Batman Begins'
# We call the `recommend()` function with the movie title `'Batman Begins'` to display the top 5 movies similar to it based on cosine similarity.

# %%
recommend('Batman Begins')
# Out:
# The Dark Knight
# The Dark Knight Rises
# Batman
# Batman & Robin
# Batman

# %%
import pickle

# %%
# pickle.dump(new_df,open('movies.pkl','wb'))

# %%
new_df['title'].values
# Out:
# array(['Avatar', "Pirates of the Caribbean: At World's End", 'Spectre',
#        ..., 'Signed, Sealed, Delivered', 'Shanghai Calling',
#        'My Date with Drew'], dtype=object)

# %%
pickle.dump(new_df.to_dict(),open('movie_dict.pkl','wb')) # it will dump the dataframe to a pickle file

# %%
pickle.dump(similarity,open('similarity.pkl','wb')) # it will dump the similarity matrix to a pickle file
